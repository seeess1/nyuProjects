# %% [markdown]
# # Overview
#
# The purpose of this project was to experiment with different ways to query a database containing a large volume of CitiBike trip data. The data was preloaded into CartoDB and queried via SQL.

# %% [markdown]
# ## Setup

# %%
try:
    import urllib2 as ulib
except ImportError:
    import urllib3 as ulib

try:
    from StringIO import BytesIO as io
except ImportError:
    from io import BytesIO as io

try:
    from urllib import urlencode as urlencode
except ImportError:
    from urllib.parse import urlencode as urlencode
    
try:
    from urllib import urlopen as urlopen
except ImportError:
    from urllib.request import urlopen as urlopen
    
try:
    from urllib2 import HTTPError as HTTPError
except ImportError:
    from urllib.error import HTTPError as HTTPError

import ast
import pandas as pd
from geopy.distance import great_circle

# %% [markdown]
# ### Query functions

# %%
API_URL = 'https://fb55.carto.com:443/api/v2/sql?q='

def queryCartoDB(query, formatting = 'CSV', source = API_URL):
    '''queries carto datasets from a given carto account
    Arguments: 
    query - string: a valid sql query string
    format - outlut format  OPTIONAL (default CSV)
    source - a valid sql api endpoint OPTIONAL (default carto fb55 account)
    Returns:
    the return of the sql query AS A STRING
    NOTES:
    designed for the carto API, tested only with CSV return format'''
    
    
    data = urlencode({'format': formatting, 'q': query}).encode("utf-8")
    try:
        response = urlopen(source, data)
        return response.read()
    except HTTPError as e:
        raise (ValueError('\n'.join(ast.literal_eval(e.readline())['error'])))
        
def get_data(query):
    try:
        return pd.read_csv(io(queryCartoDB(query)), sep = ',')
    except ValueError as v:
        print (str(v))

# %%
# Get all the records and sort by start_station_id, then by tripduration (for trips <= 3 hrs)
query = '''SELECT * FROM fb55.citibike
WHERE tripduration <= (3*60*60)
ORDER BY start_station_id DESC, tripduration DESC;
'''
table1 = get_data(query)
table1.head(10)
# Out:
#    the_geom          start_station_name  the_geom_webmercator  field_1  \
# 0       NaN  South End Ave & Liberty St                   NaN     1576
# 1       NaN  South End Ave & Liberty St                   NaN     8891
# 2       NaN  South End Ave & Liberty St                   NaN    23568
# 3       NaN  South End Ave & Liberty St                   NaN    27243
# 4       NaN  South End Ave & Liberty St                   NaN    10232
# 5       NaN  South End Ave & Liberty St                   NaN     6846
# 6       NaN  South End Ave & Liberty St                   NaN    44708
# 7       NaN  South End Ave & Liberty St                   NaN    11648
# 8       NaN  South End Ave & Liberty St                   NaN     1297
# 9       NaN  South End Ave & Liberty St                   NaN    17637
#
#    start_station_longitude  tripduration               starttime  \
# 0               -74.015756          7225  2015-02-01 11:46:00+00
# 1               -74.015756          2139  2015-02-03 09:33:00+00
# 2               -74.015756          2131  2015-02-05 08:42:00+00
# 3               -74.015756          1977  2015-02-05 16:11:00+00
# 4               -74.015756          1977  2015-02-03 16:04:00+00
# 5               -74.015756          1976  2015-02-02 09:21:00+00
# 6               -74.015756          1920  2015-02-07 18:36:00+00
# 7               -74.015756          1908  2015-02-03 18:54:00+00
# 8               -74.015756          1900  2015-02-01 11:14:00+00
# 9               -74.015756          1830  2015-02-04 16:33:00+00
#
#                  stoptime  start_station_id  cartodb_id  \
# 0  2015-02-01 13:47:00+00              3002        1506
# 1  2015-02-03 10:09:00+00              3002        8831
# 2  2015-02-05 09:17:00+00              3002       23529
# 3  2015-02-05 16:44:00+00              3002       27203
# 4  2015-02-03 16:37:00+00              3002       10173
# 5  2015-02-02 09:53:00+00              3002        6781
# 6  2015-02-07 19:08:00+00              3002       44703
# 7  2015-02-03 19:26:00+00              3002       11587
# 8  2015-02-01 11:45:00+00              3002        1228
# 9  2015-02-04 17:04:00+00              3002       17590
#
#    start_station_latitude  end_station_id          end_station_name  \
# 0               40.711512             499        Broadway & W 60 St
# 1               40.711512             510           W 51 St & 6 Ave
# 2               40.711512             359        E 47 St & Park Ave
# 3               40.711512             318  E 43 St & Vanderbilt Ave
# 4               40.711512             318  E 43 St & Vanderbilt Ave
# 5               40.711512             494           W 26 St & 8 Ave
# 6               40.711512             410   Suffolk St & Stanton St
# 7               40.711512             279      Peck Slip & Front St
# 8               40.711512             525          W 34 St & 11 Ave
# 9               40.711512             318  E 43 St & Vanderbilt Ave
#
#    end_station_latitude  end_station_longitude  bikeid    usertype  \
# 0             40.769155             -73.981918   21202    Customer
# 1             40.760660             -73.980420   15552  Subscriber
# 2             40.755103             -73.974987   21473  Subscriber
# 3             40.753202             -73.977987   20069  Subscriber
# 4             40.753202             -73.977987   15309  Subscriber
# 5             40.747348             -73.997236   19665  Subscriber
# 6             40.720664             -73.985180   15443  Subscriber
# 7             40.707873             -74.001670   19133  Subscriber
# 8             40.755942             -74.002116   17849    Customer
# 9             40.753202             -73.977987   20246  Subscriber
#
#    birth_year  gender
# 0         NaN       0
# 1      1958.0       1
# 2      1985.0       1
# 3      1969.0       1
# 4      1969.0       1
# 5      1959.0       1
# 6      1964.0       2
# 7      1996.0       1
# 8         NaN       0
# 9      1969.0       1

# %%
# Select head of data
query = '''
SELECT * FROM fb55.citibike
'''
table1 = get_data(query)
table1.head(10)
# Out:
#    the_geom    start_station_name  the_geom_webmercator  field_1  \
# 0       NaN    E 20 St & Park Ave                   NaN      175
# 1       NaN      W 43 St & 10 Ave                   NaN     1159
# 2       NaN     E 6 St & Avenue B                   NaN     2827
# 3       NaN       E 12 St & 3 Ave                   NaN     4961
# 4       NaN       W 41 St & 8 Ave                   NaN     6156
# 5       NaN       5 Ave & E 29 St                   NaN     7433
# 6       NaN  Allen St & Hester St                   NaN     7779
# 7       NaN       E 39 St & 3 Ave                   NaN     8327
# 8       NaN      10 Ave & W 28 St                   NaN     9435
# 9       NaN        E 2 St & 2 Ave                   NaN    10472
#
#    start_station_longitude  tripduration               starttime  \
# 0               -73.987520          1090  2015-02-01 01:23:00+00
# 1               -73.994618           682  2015-02-01 10:55:00+00
# 2               -73.981854           751  2015-02-01 13:59:00+00
# 3               -73.988900           272  2015-02-01 17:28:00+00
# 4               -73.990026           240  2015-02-01 21:36:00+00
# 5               -73.986831           376  2015-02-02 17:44:00+00
# 6               -73.991908          1217  2015-02-02 20:12:00+00
# 7               -73.976049           441  2015-02-03 08:02:00+00
# 8               -74.001768          1475  2015-02-03 12:31:00+00
# 9               -73.990697           420  2015-02-03 16:45:00+00
#
#                  stoptime  start_station_id  cartodb_id  \
# 0  2015-02-01 01:42:00+00               503         107
# 1  2015-02-01 11:07:00+00               515        1088
# 2  2015-02-01 14:11:00+00               317        2759
# 3  2015-02-01 17:32:00+00               483        4893
# 4  2015-02-01 21:40:00+00               477        6090
# 5  2015-02-02 17:50:00+00               474        7367
# 6  2015-02-02 20:32:00+00               361        7712
# 7  2015-02-03 08:10:00+00               167        8263
# 8  2015-02-03 12:56:00+00               489        9375
# 9  2015-02-03 16:52:00+00               403       10411
#
#    start_station_latitude  end_station_id         end_station_name  \
# 0               40.738274             229           Great Jones St
# 1               40.760094             490          8 Ave & W 33 St
# 2               40.724537             466          W 25 St & 6 Ave
# 3               40.732233             345          W 13 St & 6 Ave
# 4               40.756405             490          8 Ave & W 33 St
# 5               40.745168             537  Lexington Ave & E 24 St
# 6               40.716059             461          E 20 St & 2 Ave
# 7               40.748901             526          E 33 St & 5 Ave
# 8               40.750664             455          1 Ave & E 44 St
# 9               40.725029             297          E 15 St & 3 Ave
#
#    end_station_latitude  end_station_longitude  bikeid    usertype  \
# 0             40.727434             -73.993790   19718  Subscriber
# 1             40.751551             -73.993934   21501  Subscriber
# 2             40.743954             -73.991449   14788  Subscriber
# 3             40.736494             -73.997044   16219  Subscriber
# 4             40.751551             -73.993934   18266    Customer
# 5             40.740259             -73.984092   18048  Subscriber
# 6             40.735877             -73.982050   19732    Customer
# 7             40.747659             -73.984907   21518  Subscriber
# 8             40.750020             -73.969053   19863  Subscriber
# 9             40.734232             -73.986923   19257  Subscriber
#
#    birth_year  gender
# 0      1961.0       1
# 1      1981.0       1
# 2      1990.0       1
# 3      1961.0       1
# 4         NaN       0
# 5      1977.0       1
# 6         NaN       0
# 7      1975.0       1
# 8      1984.0       2
# 9      1984.0       1

# %%
# Select tail of data
query = '''
SELECT * FROM fb55.citibike
'''
table1 = get_data(query)
table1.tail(10)
# Out:
#        the_geom     start_station_name  the_geom_webmercator  field_1  \
# 46190       NaN        W 17 St & 8 Ave                   NaN    46190
# 46191       NaN       W 47 St & 10 Ave                   NaN    46191
# 46192       NaN  Warren St & Church St                   NaN    46192
# 46193       NaN        E 20 St & 2 Ave                   NaN    46193
# 46194       NaN        1 Ave & E 44 St                   NaN    46194
# 46195       NaN        W 20 St & 8 Ave                   NaN    46195
# 46196       NaN        5 Ave & E 29 St                   NaN    46196
# 46197       NaN        5 Ave & E 29 St                   NaN    46197
# 46198       NaN     Carmine St & 6 Ave                   NaN    46198
# 46199       NaN         E 4 St & 2 Ave                   NaN    46199
#
#        start_station_longitude  tripduration               starttime  \
# 46190               -74.001497           306  2015-02-07 23:55:00+00
# 46191               -73.993012          1248  2015-02-07 23:56:00+00
# 46192               -74.009106          1165  2015-02-07 23:56:00+00
# 46193               -73.982050           993  2015-02-07 23:56:00+00
# 46194               -73.969053          1422  2015-02-07 23:57:00+00
# 46195               -74.000040           689  2015-02-07 23:57:00+00
# 46196               -73.986831           428  2015-02-07 23:57:00+00
# 46197               -73.986831           392  2015-02-07 23:57:00+00
# 46198               -74.002150           548  2015-02-07 23:58:00+00
# 46199               -73.989780           917  2015-02-07 23:59:00+00
#
#                      stoptime  start_station_id  cartodb_id  \
# 46190  2015-02-08 00:01:00+00               116       46191
# 46191  2015-02-08 00:17:00+00               495       46192
# 46192  2015-02-08 00:15:00+00               152       46193
# 46193  2015-02-08 00:13:00+00               461       46194
# 46194  2015-02-08 00:20:00+00               455       46195
# 46195  2015-02-08 00:08:00+00               470       46196
# 46196  2015-02-08 00:04:00+00               474       46197
# 46197  2015-02-08 00:03:00+00               474       46198
# 46198  2015-02-08 00:08:00+00               368       46199
# 46199  2015-02-08 00:15:00+00               439       46200
#
#        start_station_latitude  end_station_id          end_station_name  \
# 46190               40.741776             494           W 26 St & 8 Ave
# 46191               40.762699             432         E 7 St & Avenue A
# 46192               40.714740             325           E 19 St & 3 Ave
# 46193               40.735877             295      Pike St & E Broadway
# 46194               40.750020             265  Stanton St & Chrystie St
# 46195               40.743453             325           E 19 St & 3 Ave
# 46196               40.745168             325           E 19 St & 3 Ave
# 46197               40.745168             325           E 19 St & 3 Ave
# 46198               40.730386             334           W 20 St & 7 Ave
# 46199               40.726281             417    Barclay St & Church St
#
#        end_station_latitude  end_station_longitude  bikeid    usertype  \
# 46190             40.747348             -73.997236   14736  Subscriber
# 46191             40.726218             -73.983799   16300  Subscriber
# 46192             40.736245             -73.984738   16978  Subscriber
# 46193             40.714067             -73.992939   16722  Subscriber
# 46194             40.722293             -73.991475   20184  Subscriber
# 46195             40.736245             -73.984738   15585  Subscriber
# 46196             40.736245             -73.984738   16395  Subscriber
# 46197             40.736245             -73.984738   15545  Subscriber
# 46198             40.742388             -73.997262   19540  Subscriber
# 46199             40.712912             -74.010202   20998  Subscriber
#
#        birth_year  gender
# 46190      1983.0       2
# 46191      1984.0       1
# 46192      1959.0       1
# 46193      1974.0       1
# 46194      1960.0       2
# 46195      1953.0       1
# 46196      1986.0       2
# 46197      1986.0       1
# 46198      1983.0       2
# 46199      1965.0       2

# %%
# Select all unique start_station_id numbers
query = '''
SELECT DISTINCT start_station_id FROM fb55.citibike
ORDER BY start_station_id ASC
'''
table4 = get_data(query)
table4
# Out:
#      start_station_id  Unnamed: 1
# 0                  72         NaN
# 1                  79         NaN
# 2                  82         NaN
# 3                  83         NaN
# 4                 116         NaN
# 5                 119         NaN
# 6                 120         NaN
# 7                 127         NaN
# 8                 128         NaN
# 9                 137         NaN
# 10                143         NaN
# 11                144         NaN
# 12                146         NaN
# 13                147         NaN
# 14                150         NaN
# 15                151         NaN
# 16                152         NaN
# 17                153         NaN
# 18                157         NaN
# 19                160         NaN
# 20                161         NaN
# 21                164         NaN
# 22                167         NaN
# 23                168         NaN
# 24                173         NaN
# 25                174         NaN
# 26                195         NaN
# 27                212         NaN
# 28                216         NaN
# 29                217         NaN
# ..                ...         ...
# 297               525         NaN
# 298               526         NaN
# 299               527         NaN
# 300               528         NaN
# 301               529         NaN
# 302               530         NaN
# 303               531         NaN
# 304               532         NaN
# 305               533         NaN
# 306               534         NaN
# 307               537         NaN
# 308               538         NaN
# 309               539         NaN
# 310               545         NaN
# 311               546         NaN
# 312              2000         NaN
# 313              2001         NaN
# 314              2002         NaN
# 315              2004         NaN
# 316              2005         NaN
# 317              2006         NaN
# 318              2008         NaN
# 319              2009         NaN
# 320              2010         NaN
# 321              2012         NaN
# 322              2017         NaN
# 323              2021         NaN
# 324              2022         NaN
# 325              2023         NaN
# 326              3002         NaN
#
# [327 rows x 2 columns]

# %%
# Count total trips
query = '''
SELECT COUNT(cartodb_id)
FROM fb55.citibike
'''

table5 = get_data(query)
table5
# Out:
#    count  Unnamed: 1
# 0  46200         NaN

# %%
# Select max min avg trip duration

query = '''
SELECT MAX(tripduration) AS trip_dur_max, 
MIN(tripduration) AS trip_dur_min, 
AVG(tripduration) AS trip_dur_avg
FROM fb55.citibike
'''
table6 = get_data(query)
table6
# Out:
#    trip_dur_max  trip_dur_min  trip_dur_avg
# 0         43016            60    675.865823

# %%
# Select all the trips that started on 2-2-15
query = '''
SELECT * FROM fb55.citibike
WHERE starttime::date = '2015-02-02'
'''
table7 = get_data(query)
table7.head(5)
# Out:
#    the_geom    start_station_name  the_geom_webmercator  field_1  \
# 0       NaN       5 Ave & E 29 St                   NaN     7433
# 1       NaN  Allen St & Hester St                   NaN     7779
# 2       NaN     E 5 St & Avenue C                   NaN       11
# 3       NaN       9 Ave & W 16 St                   NaN      627
# 4       NaN       9 Ave & W 16 St                   NaN      991
#
#    start_station_longitude  tripduration               starttime  \
# 0               -73.986831           376  2015-02-02 17:44:00+00
# 1               -73.991908          1217  2015-02-02 20:12:00+00
# 2               -73.979955          1312  2015-02-02 11:07:00+00
# 3               -74.004432           444  2015-02-02 00:40:00+00
# 4               -74.004432           438  2015-02-02 00:40:00+00
#
#                  stoptime  start_station_id  cartodb_id  \
# 0  2015-02-02 17:50:00+00               474        7367
# 1  2015-02-02 20:32:00+00               361        7712
# 2  2015-02-02 11:29:00+00               393        6920
# 3  2015-02-02 00:48:00+00               463        6477
# 4  2015-02-02 00:47:00+00               463        6478
#
#    start_station_latitude  end_station_id         end_station_name  \
# 0               40.745168             537  Lexington Ave & E 24 St
# 1               40.716059             461          E 20 St & 2 Ave
# 2               40.722992             476          E 31 St & 3 Ave
# 3               40.742065             489         10 Ave & W 28 St
# 4               40.742065             489         10 Ave & W 28 St
#
#    end_station_latitude  end_station_longitude  bikeid    usertype  \
# 0             40.740259             -73.984092   18048  Subscriber
# 1             40.735877             -73.982050   19732    Customer
# 2             40.743943             -73.979661   17720  Subscriber
# 3             40.750664             -74.001768   20233  Subscriber
# 4             40.750664             -74.001768   20264  Subscriber
#
#    birth_year  gender
# 0      1977.0       1
# 1         NaN       0
# 2      1955.0       1
# 3      1971.0       1
# 4      1981.0       2

# %%
# Get all the weekend trips
query = '''
SELECT *, EXTRACT(dow FROM starttime::date) AS dow
FROM fb55.citibike
WHERE EXTRACT(dow FROM starttime::date) IN (0,6);
'''
table9 = get_data(query)
table9
# Out:
#        the_geom  start_station_latitude  the_geom_webmercator  field_1  \
# 0           NaN               40.738274                   NaN      175
# 1           NaN               40.760094                   NaN     1159
# 2           NaN               40.724537                   NaN     2827
# 3           NaN               40.732233                   NaN     4961
# 4           NaN               40.756405                   NaN     6156
# 5           NaN               40.735877                   NaN    39894
# 6           NaN               40.769155                   NaN    41512
# 7           NaN               40.722281                   NaN    41595
# 8           NaN               40.727434                   NaN    41806
# 9           NaN               40.736494                   NaN    42316
# 10          NaN               40.755942                   NaN    42532
# 11          NaN               40.756405                   NaN    42915
# 12          NaN               40.738177                   NaN    44448
# 13          NaN               40.734232                   NaN    44744
# 14          NaN               40.750200                   NaN    44834
# 15          NaN               40.744023                   NaN    45301
# 16          NaN               40.751551                   NaN        0
# 17          NaN               40.752996                   NaN        1
# 18          NaN               40.739713                   NaN        2
# 19          NaN               40.740343                   NaN        3
# 20          NaN               40.763414                   NaN        4
# 21          NaN               40.727434                   NaN        5
# 22          NaN               40.730386                   NaN        6
# 23          NaN               40.732233                   NaN        7
# 24          NaN               40.742388                   NaN        8
# 25          NaN               40.729538                   NaN        9
# 26          NaN               40.744876                   NaN       10
# 27          NaN               40.750200                   NaN       38
# 28          NaN               40.741776                   NaN       49
# 29          NaN               40.734232                   NaN       50
# ...         ...                     ...                   ...      ...
# 13201       NaN               40.729039                   NaN    46170
# 13202       NaN               40.716059                   NaN    46171
# 13203       NaN               40.714740                   NaN    46172
# 13204       NaN               40.732233                   NaN    46173
# 13205       NaN               40.683125                   NaN    46174
# 13206       NaN               40.716059                   NaN    46175
# 13207       NaN               40.740343                   NaN    46176
# 13208       NaN               40.732241                   NaN    46177
# 13209       NaN               40.743943                   NaN    46178
# 13210       NaN               40.769155                   NaN    46179
# 13211       NaN               40.730386                   NaN    46180
# 13212       NaN               40.759923                   NaN    46181
# 13213       NaN               40.683125                   NaN    46182
# 13214       NaN               40.760193                   NaN    46183
# 13215       NaN               40.766953                   NaN    46184
# 13216       NaN               40.766953                   NaN    46185
# 13217       NaN               40.724055                   NaN    46186
# 13218       NaN               40.760660                   NaN    46187
# 13219       NaN               40.734927                   NaN    46188
# 13220       NaN               40.735324                   NaN    46189
# 13221       NaN               40.741776                   NaN    46190
# 13222       NaN               40.762699                   NaN    46191
# 13223       NaN               40.714740                   NaN    46192
# 13224       NaN               40.735877                   NaN    46193
# 13225       NaN               40.750020                   NaN    46194
# 13226       NaN               40.743453                   NaN    46195
# 13227       NaN               40.745168                   NaN    46196
# 13228       NaN               40.745168                   NaN    46197
# 13229       NaN               40.730386                   NaN    46198
# 13230       NaN               40.726281                   NaN    46199
#
#        start_station_longitude  tripduration               starttime  \
# 0                   -73.987520          1090  2015-02-01 01:23:00+00
# 1                   -73.994618           682  2015-02-01 10:55:00+00
# 13206       46176             504             1 Ave & E 15 St
# 13207       46177             380            W 4 St & 7 Ave S
# 13208       46178             368          Carmine St & 6 Ave
# 13209       46179             504             1 Ave & E 15 St
# 13210       46180             160     E 37 St & Lexington Ave
# 13211       46181             531      Forsyth St & Broome St
# 13212       46182             478            11 Ave & W 41 St
# 13213       46183             471     Grand St & Havemeyer St
# 13214       46184             247      Perry St & Bleecker St
# 13215       46185             488             W 39 St & 9 Ave
# 13216       46186             488             W 39 St & 9 Ave
# 13217       46187            3002  South End Ave & Liberty St
# 13218       46188             450             W 49 St & 8 Ave
# 13219       46189             404             9 Ave & W 14 St
# 13220       46190             466             W 25 St & 6 Ave
# 13221       46191             494             W 26 St & 8 Ave
# 13222       46192             432           E 7 St & Avenue A
# 13223       46193             325             E 19 St & 3 Ave
# 13224       46194             295        Pike St & E Broadway
# 13225       46195             265    Stanton St & Chrystie St
# 13226       46196             325             E 19 St & 3 Ave
# 13227       46197             325             E 19 St & 3 Ave
# 13228       46198             325             E 19 St & 3 Ave
# 13229       46199             334             W 20 St & 7 Ave
# 13230       46200             417      Barclay St & Church St
#
#        end_station_latitude  end_station_longitude  bikeid    usertype  \
# 0                 40.727434             -73.993790   19718  Subscriber
# 1                 40.751551             -73.993934   21501  Subscriber
# 2                 40.743954             -73.991449   14788  Subscriber
# 3                 40.736494             -73.997044   16219  Subscriber
# 4                 40.751551             -73.993934   18266    Customer
# 5                 40.741740             -73.994156   17278  Subscriber
# 6                 40.754666             -73.991382   15224  Subscriber
# 7                 40.724677             -73.987834   21461  Subscriber
# 8                 40.739713             -73.994564   14621  Subscriber
# 9                 40.745497             -74.001971   21362  Subscriber
# 10                40.749718             -74.002950   14549    Customer
# 11                40.745497             -74.001971   20216  Subscriber
# 12                40.742909             -73.977061   15948  Subscriber
# 13                40.739126             -73.979738   15367  Subscriber
# 14                40.738177             -73.977387   20702  Subscriber
# 15                40.736245             -73.984738   20296  Subscriber
# 16                40.760193             -73.991255   15185  Subscriber
# 17                40.760094             -73.994618   16452  Subscriber
# 18                40.750450             -73.994811   16741  Subscriber
# 19                40.746745             -74.007756   16951  Subscriber
# 20                40.750450             -73.994811   16897  Subscriber
# 21                40.736529             -74.006180   16722  Subscriber
# 22                40.738274             -73.987520   15196  Subscriber
# 23                40.741740             -73.994156   19409    Customer
# 24                40.737050             -73.990093   21456    Customer
# 25                40.744023             -73.976056   14878  Subscriber
# 26                40.750450             -73.994811   16042  Subscriber
# 27                40.756800             -73.982912   18472  Subscriber
# 28                40.750664             -74.001768   19071  Subscriber
# 29                40.744023             -73.976056   21448    Customer
# ...                     ...                    ...     ...         ...
# 13201             40.741740             -73.994156   15733  Subscriber
# 13202             40.732219             -73.981656   16931  Subscriber
# 13203             40.720196             -73.989978   17202  Subscriber
# 13204             40.726281             -73.989780   20314  Subscriber
# 13205             40.688070             -73.984106   21531  Subscriber
# 13206             40.732219             -73.981656   21491  Subscriber
# 13207             40.734011             -74.002939   15367  Subscriber
# 13208             40.730386             -74.002150   18978  Subscriber
# 13209             40.732219             -73.981656   19507  Subscriber
# 13210             40.748238             -73.978311   16936  Subscriber
# 13211             40.718939             -73.992663   18689  Subscriber
# 13212             40.760301             -73.998842   15781  Subscriber
# 13213             40.712868             -73.956981   15081  Subscriber
# 13214             40.735354             -74.004831   21672  Subscriber
# 13215             40.756458             -73.993722   16336  Subscriber
# 13216             40.756458             -73.993722   21609  Subscriber
# 13217             40.711512             -74.015756   19470  Subscriber
# 13218             40.762272             -73.987882   18167  Subscriber
# 13219             40.740583             -74.005509   15929  Subscriber
# 13220             40.743954             -73.991449   17541  Subscriber
# 13221             40.747348             -73.997236   14736  Subscriber
# 13222             40.726218             -73.983799   16300  Subscriber
# 13223             40.736245             -73.984738   16978  Subscriber
# 13224             40.714067             -73.992939   16722  Subscriber
# 13225             40.722293             -73.991475   20184  Subscriber
# 13226             40.736245             -73.984738   15585  Subscriber
# 13227             40.736245             -73.984738   16395  Subscriber
# 13228             40.736245             -73.984738   15545  Subscriber
# 13229             40.742388             -73.997262   19540  Subscriber
# 13230             40.712912             -74.010202   20998  Subscriber
#
#        birth_year  gender  dow
# 0          1961.0       1    0
# 1          1981.0       1    0
# 2          1990.0       1    0
# 3          1961.0       1    0
# 4             NaN       0    0
# 5          1987.0       1    6
# 6          1959.0       1    6
# 7          1968.0       1    6
# 8          1964.0       1    6
# 9          1962.0       1    6
# 10            NaN       0    6
# 11         1980.0       1    6
# 12         1991.0       1    6
# 13         1978.0       1    6
# 14         1989.0       2    6
# 15         1984.0       1    6
# 16         1983.0       2    0
# 17         1978.0       1    0
# 18         1984.0       1    0
# 19         1983.0       1    0
# 20         1966.0       2    0
# 21         1984.0       1    0
# 22         1968.0       1    0
# 23            NaN       0    0
# 24            NaN       0    0
# 25         1988.0       1    0
# 26         1956.0       1    0
# 27         1972.0       1    6
# 28         1963.0       1    6
# 29            NaN       0    6
# ...           ...     ...  ...
# 13201      1988.0       1    6
# 13202      1995.0       1    6
# 13203      1987.0       1    6
# 13204      1989.0       2    6
# 13205      1989.0       1    6
# 13206      1968.0       1    6
# 13207      1990.0       1    6
# 13208      1973.0       2    6
# 13209      1980.0       1    6
# 13210      1980.0       1    6
# 13211      1982.0       1    6
# 13212      1972.0       1    6
# 13213      1988.0       1    6
# 13214      1983.0       1    6
# 13215      1970.0       1    6
# 13216      1973.0       1    6
# 13217      1964.0       1    6
# 13218      1960.0       1    6
# 13219      1987.0       1    6
# 13220      1983.0       1    6
# 13221      1983.0       2    6
# 13222      1984.0       1    6
# 13223      1959.0       1    6
# 13224      1974.0       1    6
# 13225      1960.0       2    6
# 13226      1953.0       1    6
# 13227      1986.0       2    6
# 13228      1986.0       1    6
# 13229      1983.0       2    6
# 13230      1965.0       2    6
#
# [13231 rows x 20 columns]

# %%
# Average weekend trip duration
query = '''
SELECT avg(tripduration) AS avg_weekend_duration
FROM fb55.citibike
WHERE EXTRACT(dow FROM starttime::date) IN (0,6);
'''
table10 = get_data(query)
table10.head(5)
# Out:
#    avg_weekend_duration  Unnamed: 1
# 0            662.942181         NaN

# %%
# Get all the weekday trips
query = '''
SELECT *, EXTRACT(dow FROM starttime::date) AS dow
FROM fb55.citibike
WHERE EXTRACT(dow FROM starttime::date) BETWEEN 1 AND 5;
'''
table11 = get_data(query)
table11.head(5)
# Out:
#    the_geom  start_station_latitude  the_geom_webmercator  field_1  \
# 0       NaN               40.745168                   NaN     7433
# 1       NaN               40.716059                   NaN     7779
# 2       NaN               40.748901                   NaN     8327
# 3       NaN               40.750664                   NaN     9435
# 4       NaN               40.725029                   NaN    10472
#
#    start_station_longitude  tripduration               starttime  \
# 0               -73.986831           376  2015-02-02 17:44:00+00
# 1               -73.991908          1217  2015-02-02 20:12:00+00
# 2               -73.976049           441  2015-02-03 08:02:00+00
# 3               -74.001768          1475  2015-02-03 12:31:00+00
# 4               -73.990697           420  2015-02-03 16:45:00+00
#
#                  stoptime  start_station_id    start_station_name  cartodb_id  \
# 0  2015-02-02 17:50:00+00               474       5 Ave & E 29 St        7367
# 1  2015-02-02 20:32:00+00               361  Allen St & Hester St        7712
# 2  2015-02-03 08:10:00+00               167       E 39 St & 3 Ave        8263
# 3  2015-02-03 12:56:00+00               489      10 Ave & W 28 St        9375
# 4  2015-02-03 16:52:00+00               403        E 2 St & 2 Ave       10411
#
#    end_station_id         end_station_name  end_station_latitude  \
# 0             537  Lexington Ave & E 24 St             40.740259
# 1             461          E 20 St & 2 Ave             40.735877
# 2             526          E 33 St & 5 Ave             40.747659
# 3             455          1 Ave & E 44 St             40.750020
# 4             297          E 15 St & 3 Ave             40.734232
#
#    end_station_longitude  bikeid    usertype  birth_year  gender  dow
# 0             -73.984092   18048  Subscriber      1977.0       1    1
# 1             -73.982050   19732    Customer         NaN       0    1
# 2             -73.984907   21518  Subscriber      1975.0       1    2
# 3             -73.969053   19863  Subscriber      1984.0       2    2
# 4             -73.986923   19257  Subscriber      1984.0       1    2

# %%
# Get the weekday trip duration
query = '''
SELECT avg(tripduration) AS avg_weekday_duration
FROM fb55.citibike
WHERE EXTRACT(dow FROM starttime::date) BETWEEN 1 AND 5;
'''
table12 = get_data(query)
table12.head(5)
# Out:
#    avg_weekday_duration  Unnamed: 1
# 0            681.052292         NaN

# %%
# Group by station location
query = '''
SELECT start_station_name
FROM fb55.citibike
GROUP BY start_station_name
ORDER BY start_station_name;
'''
table13 = get_data(query)
table13
# Out:
#                 start_station_name  Unnamed: 1
# 0                 10 Ave & W 28 St         NaN
# 1                 11 Ave & W 27 St         NaN
# 2                 11 Ave & W 41 St         NaN
# 3                 11 Ave & W 59 St         NaN
# 4                 12 Ave & W 40 St         NaN
# 5                  1 Ave & E 15 St         NaN
# 6                  1 Ave & E 44 St         NaN
# 7                  2 Ave & E 31 St         NaN
# 8                  2 Ave & E 58 St         NaN
# 9          3 Ave & Schermerhorn St         NaN
# 10                 5 Ave & E 29 St         NaN
# 11               6 Ave & Broome St         NaN
# 12                6 Ave & Canal St         NaN
# 13                 6 Ave & W 33 St         NaN
# 14                 8 Ave & W 31 St         NaN
# 15                 8 Ave & W 33 St         NaN
# 16                 8 Ave & W 52 St         NaN
# 17                 9 Ave & W 14 St         NaN
# 18                 9 Ave & W 16 St         NaN
# 19                 9 Ave & W 18 St         NaN
# 20                 9 Ave & W 22 St         NaN
# 21                 9 Ave & W 45 St         NaN
# 22         Adelphi St & Myrtle Ave         NaN
# 23         Allen St & E Houston St         NaN
# 24            Allen St & Hester St         NaN
# 25         Allen St & Rivington St         NaN
# 26          Ashland Pl & Hanson Pl         NaN
# 27   Atlantic Ave & Fort Greene Pl         NaN
# 28        Atlantic Ave & Furman St         NaN
# 29              Avenue D & E 12 St         NaN
# ..                             ...         ...
# 297               W 4 St & 7 Ave S         NaN
# 298                W 51 St & 6 Ave         NaN
# 299               W 52 St & 11 Ave         NaN
# 300                W 52 St & 5 Ave         NaN
# 301                W 52 St & 9 Ave         NaN
# 302               W 53 St & 10 Ave         NaN
# 303                W 54 St & 9 Ave         NaN
# 304               W 56 St & 10 Ave         NaN
# 305                W 56 St & 6 Ave         NaN
# 306               W 59 St & 10 Ave         NaN
# 307          Warren St & Church St         NaN
# 308    Washington Ave & Greene Ave         NaN
# 309      Washington Ave & Park Ave         NaN
# 310                Washington Park         NaN
# 311          Washington Pl & 6 Ave         NaN
# 312       Washington Pl & Broadway         NaN
# 313            Washington Square E         NaN
# 314  Washington St & Gansevoort St         NaN
# 315        Water - Whitehall Plaza         NaN
# 316        Watts St & Greenwich St         NaN
# 317         W Broadway & Spring St         NaN
# 318          West St & Chambers St         NaN
# 319                 West Thames St         NaN
# 320       W Houston St & Hudson St         NaN
# 321           William St & Pine St         NaN
# 322       Willoughby Ave & Hall St         NaN
# 323   Willoughby Ave & Walworth St         NaN
# 324       Willoughby St & Fleet St         NaN
# 325   Wythe Ave & Metropolitan Ave         NaN
# 326               York St & Jay St         NaN
#
# [327 rows x 2 columns]

# %%
# Number of trips per station
query = '''
SELECT start_station_name, COUNT(cartodb_id)
FROM fb55.citibike
GROUP BY start_station_name
ORDER BY start_station_name;
'''
table14 = get_data(query)
table14
# Out:
#                 start_station_name  count
# 0                 10 Ave & W 28 St    203
# 1                 11 Ave & W 27 St    172
# 2                 11 Ave & W 41 St    229
# 3                 11 Ave & W 59 St    120
# 4                 12 Ave & W 40 St     91
# 5                  1 Ave & E 15 St    397
# 6                  1 Ave & E 44 St    110
# 7                  2 Ave & E 31 St    302
# 8                  2 Ave & E 58 St     64
# 9          3 Ave & Schermerhorn St     19
# 10                 5 Ave & E 29 St    230
# 11               6 Ave & Broome St    112
# 12                6 Ave & Canal St    101
# 13                 6 Ave & W 33 St    296
# 14                 8 Ave & W 31 St    530
# 15                 8 Ave & W 33 St    387
# 16                 8 Ave & W 52 St    133
# 17                 9 Ave & W 14 St    111
# 18                 9 Ave & W 16 St    178
# 19                 9 Ave & W 18 St    112
# 20                 9 Ave & W 22 St    281
# 21                 9 Ave & W 45 St    189
# 22         Adelphi St & Myrtle Ave     92
# 23         Allen St & E Houston St    207
# 24            Allen St & Hester St    156
# 25         Allen St & Rivington St    206
# 26          Ashland Pl & Hanson Pl    100
# 27   Atlantic Ave & Fort Greene Pl     36
# 28        Atlantic Ave & Furman St      5
# 29              Avenue D & E 12 St     19
# ..                             ...    ...
# 297               W 4 St & 7 Ave S    208
# 298                W 51 St & 6 Ave    192
# 299               W 52 St & 11 Ave    114
# 300                W 52 St & 5 Ave    146
# 301                W 52 St & 9 Ave    107
# 302               W 53 St & 10 Ave     81
# 303                W 54 St & 9 Ave     64
# 304               W 56 St & 10 Ave    140
# 305                W 56 St & 6 Ave    164
# 306               W 59 St & 10 Ave    100
# 307          Warren St & Church St     71
# 308    Washington Ave & Greene Ave     21
# 309      Washington Ave & Park Ave     50
# 310                Washington Park     37
# 311          Washington Pl & 6 Ave    113
# 312       Washington Pl & Broadway    222
# 313            Washington Square E    164
# 314  Washington St & Gansevoort St    122
# 315        Water - Whitehall Plaza     70
# 316        Watts St & Greenwich St     73
# 317         W Broadway & Spring St    159
# 318          West St & Chambers St    162
# 319                 West Thames St    107
# 320       W Houston St & Hudson St    193
# 321           William St & Pine St     95
# 322       Willoughby Ave & Hall St     35
# 323   Willoughby Ave & Walworth St     27
# 324       Willoughby St & Fleet St     57
# 325   Wythe Ave & Metropolitan Ave     45
# 326               York St & Jay St    106
#
# [327 rows x 2 columns]

# %%
# Number of trips per starting station w/in 500 meters of Times Square
query = '''
SELECT distcalc.start_station_name, COUNT(distcalc.cartodb_id)
FROM (SELECT *, 
    ST_Distance(
    CDB_LatLng(start_station_latitude,start_station_longitude)::geography,
    CDB_LatLng(40.7577,-73.9857)::geography, True) AS dist_from_tsq
    FROM fb55.citibike) AS distcalc
WHERE distcalc.dist_from_tsq <= 500
GROUP BY distcalc.start_station_name
ORDER BY distcalc.start_station_name
'''
table15 = get_data(query)
table15
# Out:
#    start_station_name  count
# 0  Broadway & W 41 St    251
# 1  Broadway & W 49 St    213
# 2     W 41 St & 8 Ave    507
# 3     W 42 St & 8 Ave    221
# 4     W 43 St & 6 Ave    112
# 5     W 45 St & 6 Ave    141
# 6     W 45 St & 8 Ave    141

# %%
# Find the station that had the longest average trip duration during weekends and within 500m of TimeSquare
query = '''
SELECT distcalc.start_station_name, AVG(distcalc.tripduration) AS avg_dur
FROM (SELECT *, 
    ST_Distance(
    CDB_LatLng(start_station_latitude,start_station_longitude)::geography,
    CDB_LatLng(40.7577,-73.9857)::geography, True) AS dist_from_tsq
    FROM fb55.citibike) AS distcalc
WHERE (distcalc.dist_from_tsq <= 500) AND (EXTRACT(dow FROM distcalc.starttime::date) IN (0,6))
GROUP BY distcalc.start_station_name
ORDER BY avg_dur DESC
'''
table16 = get_data(query)
table16.head(1)
# Out:
#    start_station_name      avg_dur
# 0  Broadway & W 49 St  1010.104167
